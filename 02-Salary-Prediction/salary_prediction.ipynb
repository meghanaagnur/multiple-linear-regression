# %%
# %pip install -r requirements.txt
# %pip install word2number
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5689 sha256=042703f7dd74c3d99e6c310de0f13318f2f5253176959637cac62edbc0cd47e5
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\53\b6\a3\32e61ad7462806c9f50279960156751ff653bb10034f01a86f
# Successfully built word2number
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from word2number import w2n
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

# %%
df = pd.read_csv('data/hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df['experience']= df['experience'].fillna('zero')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
import math
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(math.floor(df['test_score(out of 10)'].median()))
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    8.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    8.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
# %matplotlib inline
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.scatter(df[['experience']], df['salary($)'], color='red', marker='+')
plt.scatter(df[['test_score(out of 10)']], df['salary($)'], color='green', marker='*')
plt.scatter(df[['interview_score(out of 10)']], df['salary($)'], color='black', marker='o')

# %%
reg = LinearRegression()
reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)']],df['salary($)'])
# Out:
# LinearRegression()

# %%
coefficients =reg.coef_
intercept = reg.intercept_

# %%
reg.predict([[2,9,6]])
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %%
predicted_salary = 2 * coefficients[0] + 9 * coefficients[1] + 6 * coefficients[2] + intercept
print(predicted_salary)
# Out:
# 53205.96797671033

# %%
reg.predict([[12,10,10]])
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92002.18340611])

# %%
predicted_salary = 12 * coefficients[0] + 10 * coefficients[1] + 10 * coefficients[2] + intercept
print(predicted_salary)
# Out:
# 92002.18340611353

# %%
X = df[['experience','test_score(out of 10)','interview_score(out of 10)']]
y = df['salary($)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5, random_state=42)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
results = X_test.copy()
results["Actual salary"] = y_test.values
results["Predicted Salary"] = y_pred

# %%
results
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  \
# 1           0                    8.0                           6
# 5           3                    7.0                          10
# 0           0                    8.0                           9
# 7          11                    7.0                           8
#
#    Actual salary  Predicted Salary
# 1          45000      57440.677966
# 5          62000      59389.830508
# 0          50000      57389.830508
# 7          80000      71084.745763

# %%
print(X_test)

print(y_pred)

print(reg.coef_)

print(reg.intercept_)
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 1           0                    8.0                           6
# 5           3                    7.0                          10
# 0           0                    8.0                           9
# 7          11                    7.0                           8
# [57440.6779661  59389.83050847 57389.83050847 71084.74576271]
# [1457.62711864 2355.93220339  -16.94915254]
# 38694.915254237254

# %%
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

print(f"R² Score : {r2:.4f}")
print(f"MAE      : {mae:.2f}")
print(f"MSE      : {mse:.2f}")
print(f"RMSE     : {rmse:.2f}")
# Out:
# R² Score : 0.5932
# MAE      : 7838.98
# MSE      : 73918701.52
# RMSE     : 8597.60

# %%
plt.figure(figsize=(10,6))
plt.xlabel("Actual salary")
plt.ylabel("Predicted salary")
plt.title("Actual vs Predicted Salary")
plt.scatter(results["Actual salary"],results["Predicted Salary"], color = 'pink', marker='o', label="Predictions")
plt.plot([results['Actual salary'].min(),results['Actual salary'].max()],[results['Actual salary'].min(),results['Actual salary'].max()],color= 'black', linestyle= "--", label="Actual values")
plt.legend()
